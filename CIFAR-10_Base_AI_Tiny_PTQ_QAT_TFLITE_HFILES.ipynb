# %%
import pickle
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import timeit
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, BatchNormalization
import tensorflow_model_optimization as tfmot
from tensorflow.keras.models import load_model
import os


device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')
# Out:
# 2023-05-18 00:40:41.847062: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 00:40:42.383144: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-18 00:40:42.383189: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-18 00:40:42.383193: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-05-18 00:40:43.297691: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 00:40:43.340680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-18 00:40:43.369269: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-05-18 00:40:43.369303: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# This error most likely means that this notebook is not configured to use a GPU.  Change this in Notebook Settings via the command palette (cmd/ctrl-shift-P) or the Edit menu.
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[1], line 27
#      22 if device_name != '/device:GPU:0':
#      23   print(
#      24       '\n\nThis error most likely means that this notebook is not '
#      25       'configured to use a GPU.  Change this in Notebook Settings via the '
#      26       'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
# ---> 27   raise SystemError('GPU device not found')
#
# SystemError: GPU device not found

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Load the CIFAR-10 dataset
data_path = 'cifar-10-batches-py/'
train_data = []
train_labels = []
for i in range(1, 6):
    batch = unpickle(data_path + 'data_batch_' + str(i))
    train_data.append(batch[b'data'])
    train_labels += batch[b'labels']
    
    
train_data = np.concatenate(train_data)
train_data = train_data.reshape((50000, 3, 32, 32)).transpose(0, 2, 3, 1)
test_data = unpickle(data_path + 'test_batch')[b'data']
test_data = test_data.reshape((10000, 3, 32, 32)).transpose(0, 2, 3, 1)
train_labels = np.array(train_labels)
test_labels = np.array(unpickle(data_path + 'test_batch')[b'labels'])

# Print the number of features, classes, and training samples for CIFAR-10
print("CIFAR-10")
print("Number of features:", train_data.shape[1:])
print("Number of classes:", len(np.unique(train_labels)))
print("Number of training samples:", train_data.shape[0])

# Shuffle your dataset
train_data, train_labels = shuffle(train_data, train_labels, random_state=42)
test_data, test_labels = shuffle(test_data, test_labels, random_state=42)

# Normalize pixel values
x_train = train_data.astype('float32') / 255.0
x_test = test_data.astype('float32') / 255.0

# Convert labels to categorical format
y_train = to_categorical(train_labels, num_classes=10)
y_test = to_categorical(test_labels, num_classes=10)

# create data generator
datagen = ImageDataGenerator(zoom_range=[0.9,1.1],
                             rotation_range=30,
                             brightness_range=[0.9,1.1],
                             width_shift_range=0.3, 
                             height_shift_range=0.3,
                             vertical_flip=True,
                             horizontal_flip=True)
# prepare iterator
it_train = datagen.flow(x_train, y_train, batch_size=64)
# fit model
steps = int(x_train.shape[0] / 64)
# Out:
# CIFAR-10
# Number of features: (32, 32, 3)
# Number of classes: 10
# Number of training samples: 50000

# %%
model_10 = Sequential()
model_10.add(Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                    input_shape=(32, 32, 3)))
model_10.add(MaxPooling2D((2, 2)))
model_10.add(Dropout(0.1))
model_10.add(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model_10.add(MaxPooling2D((2, 2)))
model_10.add(Dropout(0.2))
model_10.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model_10.add(MaxPooling2D((2, 2)))
model_10.add(Dropout(0.3))
model_10.add(Flatten())
model_10.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model_10.add(Dropout(0.4))
model_10.add(Dense(10, activation='softmax'))

model_10.summary()

# define the ModelCheckpoint callback to save the model after each epoch
checkpoint_callback = ModelCheckpoint(filepath='model_10_gpu_Base-CubeAI_reduced_3Conv.h5', save_freq='epoch')

# compile model
opt = SGD(lr=0.001, momentum=0.9)
model_10.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Model Fit
model_10.fit(x_train,y_train,batch_size=64, epochs=100, validation_data=(x_test, y_test),callbacks=[checkpoint_callback])
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_88 (Conv2D)          (None, 32, 32, 8)         224
#
#  max_pooling2d_86 (MaxPoolin  (None, 16, 16, 8)        0
#  g2D)
#
#  dropout_94 (Dropout)        (None, 16, 16, 8)         0
#
#  conv2d_89 (Conv2D)          (None, 16, 16, 16)        1168
#
#  max_pooling2d_87 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  dropout_95 (Dropout)        (None, 8, 8, 16)          0
#
#  conv2d_90 (Conv2D)          (None, 8, 8, 32)          4640
#
#  max_pooling2d_88 (MaxPoolin  (None, 4, 4, 32)         0
#  g2D)
#
#  dropout_96 (Dropout)        (None, 4, 4, 32)          0
#
#  flatten_24 (Flatten)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 128)               65664
#
#  dropout_97 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 72,986
# Trainable params: 72,986
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1.9659 - accuracy: 0.2607 - val_loss: 1.6349 - val_accuracy: 0.3969
# Epoch 2/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.6577 - accuracy: 0.3857 - val_loss: 1.5392 - val_accuracy: 0.4481
# Epoch 3/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.5466 - accuracy: 0.4298 - val_loss: 1.3587 - val_accuracy: 0.5122
# Epoch 4/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.4800 - accuracy: 0.4610 - val_loss: 1.3277 - val_accuracy: 0.5314
# Epoch 5/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.4258 - accuracy: 0.4797 - val_loss: 1.2613 - val_accuracy: 0.5371
# Epoch 6/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.3926 - accuracy: 0.4973 - val_loss: 1.2298 - val_accuracy: 0.5568
# Epoch 7/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.3563 - accuracy: 0.5072 - val_loss: 1.2304 - val_accuracy: 0.5568
# Epoch 8/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.3295 - accuracy: 0.5224 - val_loss: 1.1918 - val_accuracy: 0.5782
# Epoch 9/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.3132 - accuracy: 0.5254 - val_loss: 1.1708 - val_accuracy: 0.5861
# Epoch 10/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2901 - accuracy: 0.5359 - val_loss: 1.1350 - val_accuracy: 0.5962
# Epoch 11/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2755 - accuracy: 0.5437 - val_loss: 1.1275 - val_accuracy: 0.6053
# Epoch 12/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2518 - accuracy: 0.5499 - val_loss: 1.1619 - val_accuracy: 0.5875
# Epoch 13/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2529 - accuracy: 0.5503 - val_loss: 1.0924 - val_accuracy: 0.6152
# Epoch 14/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2383 - accuracy: 0.5575 - val_loss: 1.0836 - val_accuracy: 0.6179
# Epoch 15/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2257 - accuracy: 0.5607 - val_loss: 1.0750 - val_accuracy: 0.6267
# Epoch 16/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2103 - accuracy: 0.5662 - val_loss: 1.0564 - val_accuracy: 0.6259
# Epoch 17/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.2063 - accuracy: 0.5669 - val_loss: 1.0284 - val_accuracy: 0.6326
# Epoch 18/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1951 - accuracy: 0.5746 - val_loss: 1.0539 - val_accuracy: 0.6337
# Epoch 19/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1839 - accuracy: 0.5783 - val_loss: 1.0736 - val_accuracy: 0.6132
# Epoch 20/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1791 - accuracy: 0.5794 - val_loss: 0.9954 - val_accuracy: 0.6515
# Epoch 21/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1715 - accuracy: 0.5828 - val_loss: 1.0154 - val_accuracy: 0.6441
# Epoch 22/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1676 - accuracy: 0.5858 - val_loss: 0.9953 - val_accuracy: 0.6541
# Epoch 23/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1621 - accuracy: 0.5862 - val_loss: 1.0138 - val_accuracy: 0.6474
# Epoch 24/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1527 - accuracy: 0.5902 - val_loss: 0.9902 - val_accuracy: 0.6556
# Epoch 25/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1491 - accuracy: 0.5919 - val_loss: 1.0065 - val_accuracy: 0.6465
# Epoch 26/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1361 - accuracy: 0.5929 - val_loss: 1.0346 - val_accuracy: 0.6356
# Epoch 27/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1366 - accuracy: 0.5964 - val_loss: 0.9653 - val_accuracy: 0.6583
# Epoch 28/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1250 - accuracy: 0.6005 - val_loss: 0.9615 - val_accuracy: 0.6600
# Epoch 29/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1263 - accuracy: 0.6002 - val_loss: 0.9901 - val_accuracy: 0.6490
# Epoch 30/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1270 - accuracy: 0.6012 - val_loss: 1.0297 - val_accuracy: 0.6305
# Epoch 31/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1250 - accuracy: 0.6026 - val_loss: 0.9477 - val_accuracy: 0.6680
# Epoch 32/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1181 - accuracy: 0.6047 - val_loss: 1.0057 - val_accuracy: 0.6445
# Epoch 33/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1130 - accuracy: 0.6083 - val_loss: 0.9818 - val_accuracy: 0.6546
# Epoch 34/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1141 - accuracy: 0.6062 - val_loss: 0.9490 - val_accuracy: 0.6631
# Epoch 35/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1071 - accuracy: 0.6109 - val_loss: 0.9899 - val_accuracy: 0.6510
# Epoch 36/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1061 - accuracy: 0.6097 - val_loss: 0.9346 - val_accuracy: 0.6755
# Epoch 37/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1086 - accuracy: 0.6092 - val_loss: 0.9768 - val_accuracy: 0.6608
# Epoch 38/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1015 - accuracy: 0.6120 - val_loss: 0.9594 - val_accuracy: 0.6602
# Epoch 39/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1005 - accuracy: 0.6127 - val_loss: 1.1130 - val_accuracy: 0.6161
# Epoch 40/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1050 - accuracy: 0.6094 - val_loss: 0.9796 - val_accuracy: 0.6538
# Epoch 41/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1020 - accuracy: 0.6102 - val_loss: 0.9364 - val_accuracy: 0.6734
# Epoch 42/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0830 - accuracy: 0.6191 - val_loss: 0.9754 - val_accuracy: 0.6574
# Epoch 43/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0883 - accuracy: 0.6157 - val_loss: 1.0150 - val_accuracy: 0.6453
# Epoch 44/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0886 - accuracy: 0.6147 - val_loss: 0.9251 - val_accuracy: 0.6784
# Epoch 45/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0871 - accuracy: 0.6166 - val_loss: 0.9192 - val_accuracy: 0.6821
# Epoch 46/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0801 - accuracy: 0.6201 - val_loss: 0.9303 - val_accuracy: 0.6750
# Epoch 47/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0794 - accuracy: 0.6156 - val_loss: 0.9296 - val_accuracy: 0.6757
# Epoch 48/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0849 - accuracy: 0.6172 - val_loss: 0.9154 - val_accuracy: 0.6827
# Epoch 49/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0809 - accuracy: 0.6171 - val_loss: 0.9194 - val_accuracy: 0.6787
# Epoch 50/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0752 - accuracy: 0.6210 - val_loss: 0.9245 - val_accuracy: 0.6746
# Epoch 51/100
# 782/782 [==============================] - 7s 10ms/step - loss: 1.0771 - accuracy: 0.6175 - val_loss: 0.9506 - val_accuracy: 0.6643
# Epoch 52/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0758 - accuracy: 0.6191 - val_loss: 0.9625 - val_accuracy: 0.6617
# Epoch 53/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0762 - accuracy: 0.6211 - val_loss: 0.9139 - val_accuracy: 0.6822
# Epoch 54/100
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0671 - accuracy: 0.6227 - val_loss: 0.9647 - val_accuracy: 0.6614
# Epoch 55/100
# 782/782 [==============================] - 7s 10ms/step - loss: 1.0632 - accuracy: 0.6262 - val_loss: 0.9044 - val_accuracy: 0.6830
# Epoch 56/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0751 - accuracy: 0.6210 - val_loss: 0.9413 - val_accuracy: 0.6740
# Epoch 57/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0610 - accuracy: 0.6266 - val_loss: 0.8935 - val_accuracy: 0.6941
# Epoch 58/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0542 - accuracy: 0.6290 - val_loss: 0.8950 - val_accuracy: 0.6884
# Epoch 59/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0639 - accuracy: 0.6232 - val_loss: 0.8854 - val_accuracy: 0.6947
# Epoch 60/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0598 - accuracy: 0.6266 - val_loss: 0.8916 - val_accuracy: 0.6941
# Epoch 61/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0540 - accuracy: 0.6263 - val_loss: 0.9399 - val_accuracy: 0.6753
# Epoch 62/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0564 - accuracy: 0.6266 - val_loss: 1.0181 - val_accuracy: 0.6504
# Epoch 63/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0505 - accuracy: 0.6325 - val_loss: 0.8872 - val_accuracy: 0.6941
# Epoch 64/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0545 - accuracy: 0.6288 - val_loss: 0.9265 - val_accuracy: 0.6751
# Epoch 65/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0573 - accuracy: 0.6287 - val_loss: 0.9019 - val_accuracy: 0.6839
# Epoch 66/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0424 - accuracy: 0.6322 - val_loss: 0.9413 - val_accuracy: 0.6727
# Epoch 67/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0569 - accuracy: 0.6282 - val_loss: 0.8872 - val_accuracy: 0.6863
# Epoch 68/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0465 - accuracy: 0.6305 - val_loss: 0.8676 - val_accuracy: 0.6978
# Epoch 69/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0486 - accuracy: 0.6308 - val_loss: 0.8964 - val_accuracy: 0.6873
# Epoch 70/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0428 - accuracy: 0.6321 - val_loss: 0.8832 - val_accuracy: 0.6890
# Epoch 71/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0525 - accuracy: 0.6291 - val_loss: 0.8680 - val_accuracy: 0.6990
# Epoch 72/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0416 - accuracy: 0.6340 - val_loss: 0.8641 - val_accuracy: 0.7000
# Epoch 73/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0436 - accuracy: 0.6306 - val_loss: 0.8986 - val_accuracy: 0.6891
# Epoch 74/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0438 - accuracy: 0.6361 - val_loss: 0.8682 - val_accuracy: 0.7021
# Epoch 75/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0329 - accuracy: 0.6365 - val_loss: 0.8791 - val_accuracy: 0.6975
# Epoch 76/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0359 - accuracy: 0.6339 - val_loss: 0.9106 - val_accuracy: 0.6834
# Epoch 77/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0396 - accuracy: 0.6326 - val_loss: 0.8709 - val_accuracy: 0.6950
# Epoch 78/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0379 - accuracy: 0.6340 - val_loss: 0.9035 - val_accuracy: 0.6862
# Epoch 79/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0354 - accuracy: 0.6353 - val_loss: 0.8590 - val_accuracy: 0.7031
# Epoch 80/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0362 - accuracy: 0.6385 - val_loss: 0.8706 - val_accuracy: 0.7048
# Epoch 81/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0314 - accuracy: 0.6353 - val_loss: 0.8684 - val_accuracy: 0.7077
# Epoch 82/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0315 - accuracy: 0.6377 - val_loss: 0.8767 - val_accuracy: 0.6967
# Epoch 83/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0402 - accuracy: 0.6359 - val_loss: 0.8950 - val_accuracy: 0.6872
# Epoch 84/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0295 - accuracy: 0.6359 - val_loss: 0.8900 - val_accuracy: 0.6915
# Epoch 85/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0295 - accuracy: 0.6371 - val_loss: 0.9104 - val_accuracy: 0.6847
# Epoch 86/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0296 - accuracy: 0.6374 - val_loss: 0.9083 - val_accuracy: 0.6825
# Epoch 87/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0277 - accuracy: 0.6369 - val_loss: 0.8359 - val_accuracy: 0.7115
# Epoch 88/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0278 - accuracy: 0.6384 - val_loss: 0.8817 - val_accuracy: 0.6954
# Epoch 89/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0298 - accuracy: 0.6371 - val_loss: 0.9218 - val_accuracy: 0.6835
# Epoch 90/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0278 - accuracy: 0.6376 - val_loss: 0.8395 - val_accuracy: 0.7135
# Epoch 91/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0120 - accuracy: 0.6449 - val_loss: 0.8564 - val_accuracy: 0.7027
# Epoch 92/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0258 - accuracy: 0.6395 - val_loss: 0.8654 - val_accuracy: 0.6998
# Epoch 93/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0233 - accuracy: 0.6416 - val_loss: 0.8578 - val_accuracy: 0.7051
# Epoch 94/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0238 - accuracy: 0.6405 - val_loss: 0.8507 - val_accuracy: 0.7086
# Epoch 95/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0167 - accuracy: 0.6413 - val_loss: 0.8484 - val_accuracy: 0.7094
# Epoch 96/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0241 - accuracy: 0.6409 - val_loss: 0.8701 - val_accuracy: 0.6968
# Epoch 97/100
# 782/782 [==============================] - 7s 9ms/step - loss: 1.0180 - accuracy: 0.6446 - val_loss: 0.8512 - val_accuracy: 0.7100
# Epoch 98/100
# 782/782 [==============================] - 7s 8ms/step - loss: 1.0200 - accuracy: 0.6404 - val_loss: 0.8498 - val_accuracy: 0.7053
# Epoch 99/100
# 782/782 [==============================] - 7s 8ms/step - loss: 1.0151 - accuracy: 0.6441 - val_loss: 0.8696 - val_accuracy: 0.7034
# Epoch 100/100
# 782/782 [==============================] - 7s 8ms/step - loss: 1.0197 - accuracy: 0.6430 - val_loss: 0.8704 - val_accuracy: 0.6980

# %%
# Convert Keras model to a tflite model
converter = tf.lite.TFLiteConverter.from_keras_model(model_10)

# Convert the model to the TensorFlow Lite format with quantization
def representative_data_gen():
    for input_value in tf.data.Dataset.from_tensor_slices(x_train).batch(1).take(100):
        yield [input_value]

tflite_model_name = 'model_10_gpu_Base-CubeAI_tiny_3Conv-PTQ'
        
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce full-int8 quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8  # or tf.uint8
converter.inference_output_type = tf.int8  # or tf.uint8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_data_gen
tflite_model = converter.convert()

open(tflite_model_name + '.tflite', 'wb').write(tflite_model)

tflite_interpreter = tf.lite.Interpreter(model_path=tflite_model_name + '.tflite')
tflite_interpreter.allocate_tensors()
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

predictions = np.zeros((len(x_test),), dtype=int)
input_scale, input_zero_point = input_details[0]["quantization"]
for i in range(len(x_test)):
    val_batch = x_test[i]
    val_batch = val_batch / input_scale + input_zero_point
    val_batch = np.expand_dims(val_batch, axis=0).astype(input_details[0]["dtype"])
    tflite_interpreter.set_tensor(input_details[0]['index'], val_batch)
    tflite_interpreter.allocate_tensors()
    tflite_interpreter.invoke()

    tflite_model_predictions = tflite_interpreter.get_tensor(output_details[0]['index'])
    #print("Prediction results shape:", tflite_model_predictions.shape)
    output = tflite_interpreter.get_tensor(output_details[0]['index'])
    predictions[i] = output.argmax()
    
sum = 0
for i in range(len(predictions)):
    if (predictions[i] == test_labels[i]):
        sum = sum + 1
accuracy_score = sum / 10000
print("Accuracy of reduced base quantized to int8 model is {}%".format(accuracy_score*100))
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmprscle91m/assets
# INFO:tensorflow:Assets written to: /tmp/tmprscle91m/assets
# /home/themandalorian/anaconda3/envs/mlonmcu_lab2/lib/python3.8/site-packages/tensorflow/lite/python/convert.py:765: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2023-05-18 01:24:16.583844: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-05-18 01:24:16.583870: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-05-18 01:24:16.584412: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmprscle91m
# 2023-05-18 01:24:16.586387: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-05-18 01:24:16.586400: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmprscle91m
# 2023-05-18 01:24:16.592523: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2023-05-18 01:24:16.593567: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2023-05-18 01:24:16.623399: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /tmp/tmprscle91m
# 2023-05-18 01:24:16.631999: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 47594 microseconds.
# 2023-05-18 01:24:16.654704: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# == Input details ==
# name: serving_default_conv2d_88_input:0
# shape: [ 1 32 32  3]
# type: <class 'numpy.int8'>
#
# == Output details ==
# name: StatefulPartitionedCall:0
# shape: [ 1 10]
# type: <class 'numpy.int8'>
# Accuracy of reduced base quantized to int8 model is 69.81%

# %%
# Function: Convert some hex value into an array for C programming
def hex_to_c_array(hex_data, var_name):

    c_str = ''

    # Create header guard
    c_str += '#ifndef ' + var_name.upper() + '_H\n'
    c_str += '#define ' + var_name.upper() + '_H\n\n'

    # Add array length at top of file
    c_str += '\nstatic const unsigned int ' + var_name + '_len = ' + str(len(hex_data)) + ';\n'

    # Declare C variable
    c_str += 'static const unsigned char ' + var_name + '[] = {'
    hex_array = []
    for i, val in enumerate(hex_data) :

        # Construct string from hex
        hex_str = format(val, '#04x')

        # Add formatting so each line stays within 80 characters
        if (i + 1) < len(hex_data):
            hex_str += ','
        if (i + 1) % 12 == 0:
            hex_str += '\n '
        hex_array.append(hex_str)

    # Add closing brace
    c_str += '\n ' + format(' '.join(hex_array)) + '\n};\n\n'

    # Close out header guard
    c_str += '#endif //' + var_name.upper() + '_H'

    return c_str

c_model_name = 'cifar10_base_tiny_3conv_ptq'
# check if dir 'cfiles' exists, if not create it
if not os.path.exists('cfiles'):
    os.makedirs('cfiles')
# Write TFLite model to a C source (or header) file
with open('cfiles/' + c_model_name + '.h', 'w') as file:
    file.write(hex_to_c_array(tflite_model, c_model_name))
